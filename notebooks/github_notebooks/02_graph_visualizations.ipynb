# %% [markdown]
# # Graph Visualizations

# %%
import os
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt

# %% [markdown]
# ## Load Dataset

# %%
BASE_DIR = os.path.dirname(os.path.abspath("__file__"))
file = os.path.join(BASE_DIR, "../datasets/social_networks_combined_dataset.xlsx")

# Load dataset
df = pd.read_excel(file)

# Preview dataset
df.head()

# %% [markdown]
# ## Run Algorithms

# %%
# Graph Visualization

# Generate network plots
# Draw graph layouts
# Visualize communities

print("Generating graph visualizations...")

# %% [markdown]
# ## Results

# %%
# Plot and visualize results
plt.show()
